# %% [markdown]
# ### Домашнее задание
#
# ## Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %% [markdown]
# ## Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %% [markdown]
# ## Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
import pandas as pd

# %%
url = 'http://www.cbr.ru/currency_base/monthly/'

valut = pd.read_html(url)[0]
data = pd.DataFrame(valut)
data
# Out:
#              0          1       2                             3       4
# 0    Цифр. код  Букв. код  Единиц                        Валюта    Курс
# 1          944        AZN       1         Азербайджанский манат  371720
# 2          008        ALL     100               Албанских леков  313089
# 3          012        DZD     100             Алжирских динаров  413238
# 4          973        AOA     100              Ангольских кванз  336419
# 5          032        ARS      10             Аргентинских песо  787783
# 6          051        AMD    1000              Армянских драмов  792805
# 7          971        AFN     100              Афганских афгани  633672
# 8          050        BDT     100             Бангладешских так  430972
# 9          048        BHD       1             Бахрейнский динар  791753
# 10         975        BGN       1                Болгарский лев  219527
# 11         068        BOB      10         Боливийских боливиано  425201
# 12         072        BWP      10               Ботсванских пул  445050
# 13         986        BRL       1              Бразильский реал  171487
# 14         096        BND       1             Брунейский доллар  212253
# 15         108        BIF    1000          Бурундийских франков  240525
# 16         348        HUF     100           Венгерских форинтов  157345
# 17         937        VEF       1  Венесуэльский боливар фуэрте  139008
# 18         410        KRW    1000          Вон Республики Корея  254881
# 19         704        VND   10000            Вьетнамских донгов  161574
# 20         270        GMD      10             Гамбийских даласи  110348
# 21         936        GHS       1                  Ганский седи  208589
# 22         324        GNF   10000            Гвинейских франков  599982
# 23         344        HKD      10          Гонконгских долларов  384842
# 24         981        GEL       1               Грузинский лари  177483
# 25         807        MKD     100  Денаров Республики Македония  702153
# 26         784        AED      10                  Дирхамов ОАЭ  812663
# 27         516        NAD      10              Долларов Намибии  397622
# 28         818        EGP      10             Египетских фунтов  543007
# 29         894        ZMK   10000               Замбийских квач  640814
# ..         ...        ...     ...                           ...     ...
# 71         985        PLN       1               Польский злотый  103238
# 72         946        RON       1                 Румынский лей  102101
# 73         682        SAR      10             Саудовских риялов  795785
# 74         748        SZL      10       Свазилендских лилангени  397839
# 75         408        KPW     100           Северокорейских вон  208662
# 76         690        SCR      10             Сейшельских рупий  270598
# 77         941        RSD     100              Сербских динаров  446375
# 78         760        SYP     100              Сирийских фунтов  654586
# 79         706        SOS    1000         Сомалийских шиллингов  205686
# 80         938        SDG       1                Суданский фунт  127174
# 81         968        SRD       1            Суринамский доллар  109438
# 82         694        SLL   10000         Сьерра-Леонских леоне  773128
# 83         972        TJS      10             Таджикских сомони  681782
# 84         764        THB     100             Таиландских батов  894891
# 85         834        TZS    1000        Танзанийских шиллингов  222505
# 86         788        TND       1               Тунисский динар  226061
# 87         800        UGX    1000         Угандийских шиллингов  156647
# 88         860        UZS    1000               Узбекских сумов  197566
# 89         858        UYU      10              Уругвайских песо  152681
# 90         608        PHP     100             Филиппинских песо  642815
# 91         262        DJF     100               Франков Джибути  173013
# 92         950        XAF    1000              Франков КФА ВЕАС  654686
# 93         952        XOF    1000             Франков КФА ВСЕАО  654686
# 94         191        HRK      10                Хорватских кун  587280
# 95         203        CZK      10                  Чешских крон  163253
# 96         152        CLP    1000                Чилийских песо  589379
# 97         144        LKR     100          Шри-Ланкийских рупий  260953
# 98         233        EEK      10                Эстонских крон  274374
# 99         230        ETB      10               Эфиопских быров  235336
# 100        710        ZAR      10        Южноафриканских рэндов  397845
#
# [101 rows x 5 columns]
